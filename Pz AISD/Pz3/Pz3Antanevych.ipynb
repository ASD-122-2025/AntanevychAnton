# %% [markdown]
# # Практичне завдання №3
# **Номер за списком:** 1
#
# ---
#
# ## Варіант 1
#
# **Завдання:**
#
# Маємо дві функції 𝑓(𝑛) = 4𝑛3 − 12𝑛 + 9, 𝑔(𝑛) = 𝑛3. Довести, що𝑓(𝑛) = Ω(𝑔(𝑛)).
#
# ### Розв'язок:

# %% [markdown]
# ## Алгоритм бульбашкового сортування

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break

# %% [markdown]
# ### Аналіз алгоритму бульбашкового сортування
#
# <table style="margin-left: 0; margin-right: auto;">
#   <tr>
#     <th>Опис</th>
#     <th>Внесок у складність</th>
#   </tr>
#   <tr>
#     <td>Зовнішній цикл <code>for i in range(n)</code></td>
#     <td>Повторюється <code>n</code> разів — <strong>O(n)</strong></td>
#   </tr>
#   <tr>
#     <td>Внутрішній цикл <code>for j in range(0, n - i - 1)</code></td>
#     <td>У сумі: <code>n(n - 1)/2</code> ітерацій — <strong>O(n²)</strong></td>
#   </tr>
#   <tr>
#     <td>Порівняння та обмін <code>if arr[j] > arr[j+1]</code></td>
#     <td>Постійна операція — <strong>O(1)</strong>, але виконується багато разів</td>
#   </tr>
#   <tr>
#     <td>Умова виходу <code>if not swapped</code></td>
#     <td>Якщо масив вже відсортований, вихід після першого проходу — <strong>O(n)</strong></td>
#   </tr>
# </table>
#
# ### Асимптотична складність
#
# <table style="margin-left: 0; margin-right: auto;">
#   <tr>
#     <th>Випадок</th>
#     <th>Часова складність</th>
#   </tr>
#   <tr>
#     <td>Найгірший (перевернутий масив)</td>
#     <td><strong>O(n²)</strong></td>
#   </tr>
#   <tr>
#     <td>Найкращий (вже відсортований масив)</td>
#     <td><strong>O(n)</strong> — завдяки перевірці <code>swapped</code></td>
#   </tr>
# </table>
#
# ### Порівняння з сортуванням вставлянням
#
# <table style="margin-left: 0; margin-right: auto;">
#   <tr>
#     <th>Критерій</th>
#     <th>Бульбашкове сортування</th>
#     <th>Сортування вставлянням</th>
#   </tr>
#   <tr>
#     <td>Найгірший випадок</td>
#     <td>O(n²)</td>
#     <td>O(n²)</td>
#   </tr>
#   <tr>
#     <td>Найкращий випадок</td>
#     <td>O(n)</td>
#     <td>O(n)</td>
#   </tr>
#   <tr>
#     <td>Середній випадок</td>
#     <td>O(n²)</td>
#     <td>O(n²)</td>
#   </tr>
#   <tr>
#     <td>Практична ефективність</td>
#     <td>Низька</td>
#     <td>Вища</td>
#   </tr>
# </table>
#
#
# ### Чому бульбашкове сортування менш ефективне на практиці?
#
# - Велика кількість непотрібних обмінів, які уповільнюють виконання.
# - Сортування вставлянням, навпаки, зменшує кількість пересувань елементів.
# - У порівнянні з **merge sort** (метод злиття), що має складність **O(n log n)**, бульбашковий метод значно програє за швидкістю навіть на середніх розмірах масиву.
# - Алгоритм злиття ефективно працює з великими обсягами даних, підтримує стабільність та дозволяє ефективну реалізацію у рекурсивному стилі.

# %% [markdown]
# | №  | Контрольнi питання                                                                 | Відповідь                                                                                     |
# |----|-----------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------|
# | 1  | Що таке асимптотична складність алгоритму сортування і чому вона важлива для порівняння алгоритмів? | Асимптотична складність визначає залежність часу/пам'яті від розміру вхідних даних (𝑛). Важлива, бо дозволяє порівнювати ефективність алгоритмів на великих даних, ігноруючи константи та апаратні особливості. |
# | 2  | Які алгоритми сортування мають квадратичну складність у найгіршому випадку? Чому це проблема для великих даних? | <ul><li>**Приклади**: Сортування бульбашкою, вибором, вставками.</li><li>**Проблема**: Час виконання зростає як 𝑂(𝑛²), що робить їх непрактичними для 𝑛 > 10⁵–10⁶ (наприклад, сортування 1 млн елементів займе ~10¹² операцій).</li></ul> |
# | 3  | В чому полягає перевага сортування злиттям над сортуванням вставками для великих наборів даних? | <ul><li>**Складність**: Злиття — 𝑂(𝑛 log 𝑛), вставки — 𝑂(𝑛²).</li><li>**Стабільність**: Злиття ефективне навіть для великих 𝑛, тоді як вставки стають повільними.</li><li>**Паралелізація**: Алгоритм злиття легше паралелізувати.</li></ul> |
# | 4  | Які алгоритми сортування використовуються у стандартних бібліотеках мов програмування? | <ul><li>**Python (Timsort)**: Гібрид злиття та вставок, 𝑂(𝑛 log 𝑛).</li><li>**Java (Arrays.sort)**: Для примітивів — швидке сортування (Quicksort), для об’єктів — Timsort.</li><li>**C++ (std::sort)**: Introsort (гібрид Quicksort, Heapsort і сортування вставками).</li></ul> |
# | 5  | Яка різниця між сортуванням злиттям і швидким сортуванням? Коли краще використовувати кожен? | <ul><li>**Різниця**: <ul><li>Злиття: гарантована 𝑂(𝑛 log 𝑛), вимагає 𝑂(𝑛) додаткової пам’яті.</li><li>Швидке сортування: середній випадок 𝑂(𝑛 log 𝑛), найгірший — 𝑂(𝑛²), але на практиці швидший через менші накладні витрати.</li></ul></li><li>**Вибір**: <ul><li>Злиття — для стабільності та великих даних.</li><li>Quicksort — для малих/середніх даних, де важлива швидкість.</li></ul></li></ul> |
# | 6  | Які фактори слід враховувати при виборі алгоритму сортування? | <ul><li>**Розмір даних**: Для малих 𝑛 — вставки (менше накладних витрат), для великих — 𝑂(𝑛 log 𝑛) алгоритми.</li><li>**Тип даних**: Чи є дані майже відсортованими (адаптивні алгоритми).</li><li>**Обмеження пам’яті**: Наявність 𝑂(1) (наприклад, Heapsort) або 𝑂(𝑛) (злиття).</li><li>**Стабільність**: Чи важливо збереження порядку однакових елементів (Timsort, злиття).</li></ul> |
