# %% [markdown]
# # Практичне завдання №4
# **Номер за списком:** 1
#
# ---
#
# ## Варіант 1
#
# **Завдання:**
#
# Оцінити асимптотичну складність алгоритму лінійного пошуку у 𝑂-
# нотації в найгіршому і в найкращому випадку. Як можна покращити алгоритм
# лінійного пошуку?
#
#
# ### Розв'язок:

# %% [markdown]
# ### Оцінка асимптотичної складності лінійного пошуку
#
# #### У **найгіршому випадку**:
# - **Складність: O(n)**
#   Алгоритм перевіряє всі `n` елементів, якщо шуканий елемент відсутній або знаходиться в кінці масиву.
#
# #### У **найкращому випадку**:
# - **Складність: O(1)**
#   Якщо шуканий елемент знаходиться на першій позиції, алгоритм завершується одразу.
#
# ### Покращення лінійного пошуку
#
# **Сортування даних** (якщо можливо):
# - Після сортування можна використовувати **бінарний пошук (O(log n))**, але це потребує додаткових витрат на підтримку відсортованого стану.
#
# **Використання хеш-таблиць (O(1) в середньому)**:
# - Якщо дані статичні або рідко змінюються, можна побудувати хеш-таблицю для миттєвого пошуку.
#
# **Оптимізація для часткових випадків**:
# - Якщо відомо, що елементи часто зустрічаються на початку масиву, можна додати перевірку "найчастіших" позицій першими.
#
# **Паралельний пошук**:
# - Для дуже великих масивів можна розпаралелити пошук по частинах даних (але це має сенс лише на багатопроцесорних системах).
#
# **Модифікації для зв’язаних списків**:
# - Для списків можна використовувати **транспонування** (після знаходження елемента переміщати його на початок, щоб при наступному пошуку він знаходився швидше).
#
# **Висновок**: Лінійний пошук залишається оптимальним для невпорядкованих даних, які часто змінюються, або для малих розмірів масивів (де накладні витрати на складніші алгоритми перевищують виграш у часі).

# %% [markdown]
# | №  | Контрольне питання                                                                 | Відповідь                                                                                     |
# |----|-----------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------|
# | 1  | Що таке алгоритм пошуку і чому він важливий у контексті комп'ютерних наук?       | Алгоритм пошуку - це процедура знаходження елемента у структурі даних. Важливий, оскільки лежить в основі роботи баз даних, інформаційних систем та інших ключових технологій. |
# | 2  | Які основні критерії оцінки ефективності алгоритмів пошуку?                      | <ul><li>Часова складність (найгірший/середній випадок)</li><li>Використання пам'яті</li><li>Вимоги до структури даних</li><li>Адаптивність до вхідних даних</li></ul> |
# | 3  | Що таке лінійний пошук, і як він працює?                                         | Лінійний пошук - це послідовне перевіряння кожного елемента масиву/списку до знаходження шуканого. Складність: O(n). |
# | 4  | Які умови повинні бути виконані для успішного застосування бінарного пошуку?     | <ul><li>Відсортований масив даних</li><li>Можливість прямого доступу до елементів</li><li>Наявність оператора порівняння</li></ul> |
# | 5  | Які переваги та недоліки використання бінарного пошуку?                          | <ul><li>Переваги: <ul><li>Швидкість (O(log n))</li><li>Ефективність для великих даних</li></ul></li><li>Недоліки: <ul><li>Вимагає відсортованих даних</li><li>Не підходить для динамічних структур</li></ul></li></ul> |
# | 6  | Що таке тернарний пошук, і в чому його відмінність від бінарного пошуку?         | <ul><li>Тернарний пошук ділить масив на 3 частини замість 2</li><li>Відмінності: <ul><li>Складність O(log₃n)</li><li>Ефективніший для деяких функцій</li><li>Вимагає більше порівнянь на ітерацію</li></ul></li></ul> |
